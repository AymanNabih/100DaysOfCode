# %%
import skedm as edm
import skedm.data as data
X = data.lorenz(sz=10000)[:,0]
import matplotlib.pyplot as plt

# %%
plt.plot(X)

# %%
E = edm.Embed(X)
max_lag = 100
mi = E.mutual_information(max_lag)

# %%
lag = 15
embed = 3
predict = 30
#predicting out to double to lag
X,y = E.embed_vectors_1d(lag,embed,predict)

# %%
plt.plot(X,y)
# Out:
# [<matplotlib.lines.Line2D at 0x272058cdc50>,
#  <matplotlib.lines.Line2D at 0x272058cde48>,
#  <matplotlib.lines.Line2D at 0x272058d4080>,
#  <matplotlib.lines.Line2D at 0x272058d4278>,
#  <matplotlib.lines.Line2D at 0x272058d4470>,
#  <matplotlib.lines.Line2D at 0x272058d4668>,
#  <matplotlib.lines.Line2D at 0x272058d4860>,
#  <matplotlib.lines.Line2D at 0x272058d4a58>,
#  <matplotlib.lines.Line2D at 0x272058d4c50>,
#  <matplotlib.lines.Line2D at 0x272058d4e48>,
#  <matplotlib.lines.Line2D at 0x27205635b00>,
#  <matplotlib.lines.Line2D at 0x272058da240>,
#  <matplotlib.lines.Line2D at 0x272058da438>,
#  <matplotlib.lines.Line2D at 0x272058da630>,
#  <matplotlib.lines.Line2D at 0x272058da828>,
#  <matplotlib.lines.Line2D at 0x272058daa20>,
#  <matplotlib.lines.Line2D at 0x272058dac18>,
#  <matplotlib.lines.Line2D at 0x272058dae10>,
#  <matplotlib.lines.Line2D at 0x272058dafd0>,
#  <matplotlib.lines.Line2D at 0x272058e0240>,
#  <matplotlib.lines.Line2D at 0x272058e0438>,
#  <matplotlib.lines.Line2D at 0x272058e0630>,
#  <matplotlib.lines.Line2D at 0x272058e0828>,
#  <matplotlib.lines.Line2D at 0x272058e0a20>,
#  <matplotlib.lines.Line2D at 0x272058e0c18>,
#  <matplotlib.lines.Line2D at 0x272058e0e10>,
#  <matplotlib.lines.Line2D at 0x272058e0fd0>,
#  <matplotlib.lines.Line2D at 0x272058e7240>,
#  <matplotlib.lines.Line2D at 0x272058e7438>,
#  <matplotlib.lines.Line2D at 0x272058e7630>]
